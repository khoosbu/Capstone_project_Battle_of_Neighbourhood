# %% [markdown]
# # Part 1 (data) :

# %% [markdown]
# ## Description :-

# %% [markdown]
# ### The data that we will be used here  is Foursquare data for Rio de Janeiro city.
# ### It will focus on venues of restaurant type.
# ### The popularity will be an indicator for how good an area is for a restaurant.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# Get longitude and latitude for Rio de Janeiro
address = 'Rio de Janeiro, Rio de Janeiro'

geolocator = Nominatim(user_agent="rio_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Rio de Janeiro is {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Rio de Janeiro is -22.9110137, -43.2093727.

# %%
# Set up Foursquare
CLIENT_ID = 'E0IMNYNCMI4Z5UR4SSDPKX44VAOMPIF1DN52LK5QQ110Y3BZ' # your Foursquare ID
CLIENT_SECRET = '4WXFQTMEH1DTBZAZXG2ZIQF4BEFUWPJA5WVBIBOHFUI5SAG4' # your Foursquare Secret
VERSION = '20200501' # Foursquare API version
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: E0IMNYNCMI4Z5UR4SSDPKX44VAOMPIF1DN52LK5QQ110Y3BZ
# CLIENT_SECRET:4WXFQTMEH1DTBZAZXG2ZIQF4BEFUWPJA5WVBIBOHFUI5SAG4

# %%
search_query = 'Restaurant'
radius = 50000
print(search_query + ' .... Done.....')
# Out:
# Restaurant .... Done.....

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=E0IMNYNCMI4Z5UR4SSDPKX44VAOMPIF1DN52LK5QQ110Y3BZ&client_secret=4WXFQTMEH1DTBZAZXG2ZIQF4BEFUWPJA5WVBIBOHFUI5SAG4&ll=-22.9110137,-43.2093727&v=20200501&query=Restaurant&radius=50000&limit=100'

# %%
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '52e81612bcbc57f1066b79f1', 'name': 'B...    False
# 1  [{'id': '4bf58dd8d48988d16b941735', 'name': 'B...    False
# 2  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...    False
# 3  [{'id': '4bf58dd8d48988d16b941735', 'name': 'B...    False
# 4  [{'id': '4bf58dd8d48988d16b941735', 'name': 'B...    False
#
#                          id                      location.address location.cc  \
# 0  56e04e1d38fa3ae11155b863                    Rua Riachuelo, 242          BR
# 1  4ece6782cc219860f521dd5d                                   NaN          BR
# 2  50e0b634e4b0f94bd8a38f47                        Navio Soberano          BR
# 3  4fc1101ee4b0557038e08c56  Rua Melo e Sousa, 122, São Cristovão          BR
# 4  4ea177ad775b5c3e82b77a2f                                   NaN          BR
#
#     location.city location.country location.crossStreet  location.distance  \
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered.head()
# Out:
#                        name            categories  \
# 0            Riá Restaurant                Bistro
# 1        Restaurante Pitada  Brazilian Restaurant
# 2       Restaurant El Duero            Restaurant
# 3  Restaurante Cheiro Verde  Brazilian Restaurant
# 4  Restaurante Sonho de Mel  Brazilian Restaurant
#
#                                 address  cc            city country  \
# 0                    Rua Riachuelo, 242  BR  Rio de Janeiro  Brasil
# 1                                   NaN  BR  Rio de Janeiro  Brasil
# 2                        Navio Soberano  BR  Rio de Janeiro  Brasil
# 3  Rua Melo e Sousa, 122, São Cristovão  BR  Rio de Janeiro  Brasil
# 4                                   NaN  BR  Rio de Janeiro  Brasil
#
#   crossStreet  distance                                   formattedAddress  \
# 0         NaN      2146   [Rua Riachuelo, 242, Rio de Janeiro, RJ, Brasil]
# 1         NaN      1828                       [Rio de Janeiro, RJ, Brasil]
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.map.Marker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)
# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.map.Marker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
