# %% [markdown]
# # Project Title - : Capstone Project - The Battle of Neighborhoods

# %% [markdown]
# ## Part 1

# %% [markdown]
# ## Problem :-
# * Where would be the best place to open a restaurant in Rio de Janeiro(Brazil) ?
# * Which place has the most reviews ?
# * Which location seems to be the most popular ?
# * Is there any a  type of restaurant that is more popular than another ?

# %% [markdown]
# ## Solution :-
#
# ### This problem will be solved using the Foursquare API,
# ### looking at the usercount and tipcount.
# ### This problem will be helpful to everyone that wants to open up a restaurant in Rio de Janeiro and
# ### the people who wants to know if it is a viable option where they intend on opening.
